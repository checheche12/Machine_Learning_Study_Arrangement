# %% [markdown]
# ### Sequence to Sequence
#
# - 문장을 넣었을 때 -> 문장이 나오도록 하는 방법
# - 이런 분야를 Natural Language Processing (NLP) 이라고 한다
# - 과거에는 문장을 하나의 고정길이 벡터로 다루는 방법이 없었다.
# - N-gram 모델 / SMT (통계적 기계 번역) 등의 방식을 사용했다.
# - ![image.png](attachment:image.png)
# - https://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf
# - 위 논문에서 최초로 단어 임베딩 + Multi Layer Perceptron 을 이용해서 언어 모델을 만들었다.
#   - 단어를 벡터로 표현하는 기술이 여기서 나왔다.
# - Word2Vec
#   - https://arxiv.org/abs/1301.3781
#   - ![image-2.png](attachment:image-2.png)
#   - 단어가 벡터공간에서 의미적으로 정렬이 될 수 있다는 것을 보여주었다.
#   - 그래서 이 때부터 어떤 문장을 벡터로 만든 뒤, 그 벡터로 비슷한 문장을 만들 수 있는 길이 열렸다.
# - LSTM (RNN 계열)
#   - ![image-3.png](attachment:image-3.png)
#   - https://arxiv.org/abs/1409.3215
#   - LSTM Encoder + LSTM Decoder 구조 로 이루어 져 있고
#   - 문장을 하나의 벡터로 만든 뒤 해당 벡터에서 다음 문장을 생성하는 식으로 동작.
#   - ![image-4.png](attachment:image-4.png)
#   -  https://arxiv.org/abs/1406.1078
#   - 위 논문에서도 거의 동시기에 Encoder / Decoder 구조를 제안했다.
# - 이와 같이 만든 LSTM은 문장이 길어지면 잊어버리는 문제가 생겨서, 이 때 Attention 매커니즘을 처음으로 도입하게 된다.
#   - ![image-5.png](attachment:image-5.png)
#   - https://arxiv.org/abs/1409.0473
#   - 문장을 하나의 벡터로 요약하는게 아니라, Decoder 가 필요할 때, Encoder 의 Hidden State 를 직접 보자 라는 아이디어.
# - Transformer
#   - ![image-6.png](attachment:image-6.png)
#   - https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf
#   - 위 논문에서 제안 된 방식이다.
#   - RNN 을 제거하고 Attention 만 사용하는 Attention 기반 구조로 변경 하였다.
#   - 학습 병렬화 + 성능이 아주 크게 증가 하였다.
#   - Transformer 도 Encoder / Decoder 구조는 그대로 가지고 있고, RNN 대신 Attention 매커니즘만 사용
# - 이후 LLM 의 시대
#  - Encoder / Decoder 를 따로 떼어서 Encoder 를 크게 쌓는 식으로 BERT 를 / Decoder 만 크게 쌓는 식으로 GPT 같은 언어 모델을 만들었다.
#  - 또한 Transformer 의 각종 문제를 해결하는 식으로 발전 해 왔다.
#  - Transformer 이후에는 아직까지는 NLP 에서 새로운 아키텍쳐가 나오지는 않았다.
