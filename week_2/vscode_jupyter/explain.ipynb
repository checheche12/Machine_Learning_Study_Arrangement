# %% [markdown]
# ### 우선 우측 상단에 보면
#
# ![image.png](attachment:image.png)
#
# 이런 항목이 있는데, 여기서 우리가 사용할 Kernel 을 선택 하여야 합니다.
#
# 우선 `ctrl + shift + p` 를 눌러서
#
# ![image-2.png](attachment:image-2.png)
#
# 해당 항목을 선택합니다.
#
#
# 그 뒤
#
# ![image-3.png](attachment:image-3.png)
#
# `Enter interpreter path` 를 클릭합니다.
#
#
# ![image-4.png](attachment:image-4.png)
#
# 절대 경로를 알고 있다면 절대 경로를 입력해주시면 되지만, 보통 절대경로를 알고있지는 않을거라
#
# Find 를 눌러주셔서 가상환경 폴더로 갑니다.
#
# 가상환경을 실행할 때는 `Windows: {가상환경이름}/Scripts/ 에서` `activate`, `Linux or Mac: {가상환경이름}/bin/` 혹은  를 실행했을건데,
#
# 이게 사실은 이 폴더에 있는 Python 을 실행하라는 Shell 명령어의 집합일 뿐입니다.
#
# 즉 해당 폴더에 존재하는 Python.exe 를 지정해주면, 해당 가상환경 이름의 venv 를 사용할 수 있습니다.
#
# 아래 예시는 Windows 예시이기 때문에, Linux / Mac 은 위에서 설명드린 경로로 이동하셔서 찾으시면 됩니다.
#
#
# ![image-5.png](attachment:image-5.png)
#
# 여기까지 하면 우측 상단에
#
# ![image-6.png](attachment:image-6.png)
#
#
# 본인의 가상환경이 뜨게 됩니다.
#
#
# 이런식으로 본인의 가상환경을 쉽게 VSCode에서 사용 가능합니다.

# %% [markdown]
# 이렇게 파이썬 커널을 실행 했다면, VSCode Jupyter 를 사용하여, 쉽게 Python 을 실행 할 수 있습니다.
#
# 아래에 있는 파이썬 코드 옆에 ![image.png](attachment:image.png) 버튼을 클릭해서, 해당 코드가 실행되는 것을 확인 해 보세요
#
#
# 위의 여러 버튼들이 있는데
#
# `Code` 는 코드를 작성할 칸을 새로 만드는 것이고
#
# `Markdown` 은 이런 설명칸을 적는 곳을 새로 만드는 것 입니다.
#
# 그 외 다른 버튼들은 눌러도 큰 일이 나지는 않는 것들이니 뭔지 한번 구경 해보셔도 되고, 굳이 해보시지 않으셔도 됩니다.
#
# 필요하면 그 때 또 설명 드리겠습니다

# %%
a = "Hello,"
b = " World!"
print(a + b)
